# %% [markdown]
# <a href="https://colab.research.google.com/github/Markgoplaydota2/lab/blob/main/km3%20zanozin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
V = 64 #m^3
p = 101325 #pa
T = 273 #K
R = 8.3145 #j/K*mol
M = (0.012 + 0.001 * 4) #kg/mol
# p * v = (m/M) * R * T
m = (p * V * M) / (R * T)
print(m)
# Out:
# 45.71069077653959

# %%
pip install CoolProp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting CoolProp
#   Downloading CoolProp-6.4.3.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 48.3 MB/s eta 0:00:00
# Installing collected packages: CoolProp
# Successfully installed CoolProp-6.4.3.post1

# %%
import numpy as np
import CoolProp.CoolProp as ct  
import matplotlib.pyplot as plt
V = 64 #m^3
p = 101330 #pa
T = 273 #K
R = 8.3145 #j/K*mol
M = (0.012 + 0.001 * 4) #kg/mol

d = ct.PropsSI("D", "T", T, "P", p, "Methane")
m = d * V
print(m)
# Out:
# 45.94507000613308

# %%
import numpy as np
import CoolProp.CoolProp as ct  
import matplotlib.pyplot as plt
V = 64 #m^3
p = 101330 #pa
T = 273 #K
R = 8.3145 #j/K*mol
M = (0.012 + 0.001 * 4) #kg/mol

q = 1
T = np.linspace(0, 600, 50000)
p = 101325
d = ct.PropsSI("D", "T", T, "P", p, "Methane")
T1 = ct.PropsSI("T","P", p, "Q", q, "Methane")
plt.plot(T, d)
plt.title("d от T")
plt.xlabel("температура T, K")
plt.ylabel("плотность d, kg/m^3")
plt.scatter(111.667, 0, color ='red')
plt.grid()
plt.show()

T = np.linspace(0, 600, 50000)
p = 101325
d = ct.PropsSI("D", "T", T, "P", p, "Methane")
T1 = ct.PropsSI("T","P", p, "Q", q, "Methane")
plt.plot(T, d*V)
plt.title("d от T")
plt.xlabel("температура T, K")
plt.ylabel("масса m, kg")
plt.scatter(111.667, 0, color ='red')
plt.grid()
plt.show()
